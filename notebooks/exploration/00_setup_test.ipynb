# %% [markdown]
# # Setup Test Notebook
#
# This notebook verifies that the development environment is correctly configured.
#
# **Purpose:** Test imports, check versions, verify polyvoice package is accessible.

# %%
# Check Python version
import sys
print(f"Python: {sys.version}")
# Out:
# Python: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
# Test polyvoice package import
import polyvoice
print(f"PolyVoice version: {polyvoice.__version__}")
# Out:
# PolyVoice version: 0.1.0

# %%
# Check key dependencies are available
packages = [
    "numpy",
    "torch",
    "transformers",
]

for pkg in packages:
    try:
        module = __import__(pkg)
        version = getattr(module, "__version__", "unknown")
        print(f"{pkg}: {version}")
    except ImportError:
        print(f"{pkg}: NOT INSTALLED (will be added in later phases)")
# Out:
# numpy: NOT INSTALLED (will be added in later phases)
# torch: NOT INSTALLED (will be added in later phases)
# transformers: NOT INSTALLED (will be added in later phases)

# %% [markdown]
# ## Environment Check Complete
#
# If you see the PolyVoice version above, the setup is working correctly.
#
# **Next steps:**
# - Explore audio data in `notebooks/exploration/`
# - Run experiments in `notebooks/experiments/`
# - Export important notebooks: `poetry run python scripts/export_notebooks.py`
